# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
# Out:
# Using TensorFlow backend.

# %%
from keras.layers import Conv2D, MaxPooling2D,Flatten

# %%
from keras import backend as K

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot

# %%
from keras.layers import Lambda
from keras.objectives import binary_crossentropy

# %%
from keras.layers import Input, Dense
from keras.models import Model

# %% [markdown]
# # Handwritten digits dataset

# %%
from keras.datasets import mnist
from keras.utils import np_utils

# %%
nb_classes = 10

# the data, shuffled and split between tran and test sets
(X_train, y_train), (X_test, y_test) = mnist.load_data()
print("X_train original shape", X_train.shape)
print("y_train original shape", y_train.shape)
# Out:
# X_train original shape (60000, 28, 28)
# y_train original shape (60000,)

# %%
print("X_test original shape", X_test.shape)
print("y_test original shape", y_test.shape)
# Out:
# X_test original shape (10000, 28, 28)
# y_test original shape (10000,)

# %%
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_train[i], cmap='gray', interpolation='none')
    plt.title("Class {}".format(y_train[i]))

# %%
X_train_orig = X_train
X_test_orig = X_test

# %%
X_train = X_train_orig.reshape(60000, 784)
X_test = X_test_orig.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (60000, 784)
# Testing matrix shape (10000, 784)

# %%
Y_train = np_utils.to_categorical(y_train, nb_classes)
Y_test = np_utils.to_categorical(y_test, nb_classes)

# %%
Y_test.shape
# Out:
# (10000, 10)

# %% [markdown]
# # Plain neural network

# %% [markdown]
# Source: https://github.com/wxs/keras-mnist-tutorial/blob/master/MNIST%20in%20Keras.ipynb

# %%
model = Sequential()
model.add(Dense(512, input_shape=(784,), activation="relu"))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                5130
# ...
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train.shape
# Out:
# (60000,)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
hist1 = model.fit(X_train[:1000], Y_train[:1000],
          batch_size=512, epochs=10,
          shuffle=True,
           verbose=1,
          validation_data=(X_test, Y_test)
         )
# Out:
# Train on 1000 samples, validate on 10000 samples
# Epoch 1/10
# 1000/1000 [==============================] - 0s 212us/step - loss: 0.0201 - acc: 1.0000 - val_loss: 0.3937 - val_acc: 0.8854
# Epoch 2/10
# 1000/1000 [==============================] - 0s 214us/step - loss: 0.0192 - acc: 1.0000 - val_loss: 0.3941 - val_acc: 0.8855
# Epoch 3/10
# 1000/1000 [==============================] - 0s 199us/step - loss: 0.0185 - acc: 1.0000 - val_loss: 0.3942 - val_acc: 0.8858
# Epoch 4/10
# 1000/1000 [==============================] - 0s 201us/step - loss: 0.0178 - acc: 1.0000 - val_loss: 0.3948 - val_acc: 0.8861
# Epoch 5/10
# 1000/1000 [==============================] - 0s 187us/step - loss: 0.0171 - acc: 1.0000 - val_loss: 0.3958 - val_acc: 0.8859
# Epoch 6/10
# 1000/1000 [==============================] - 0s 197us/step - loss: 0.0164 - acc: 1.0000 - val_loss: 0.3966 - val_acc: 0.8864
# Epoch 7/10
# ...

# %%
# The predict_classes function outputs the highest probability class
# according to the trained classifier for each input example.
predicted_classes = model.predict_classes(X_test)

# Check which items we got right / wrong
correct_indices = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test)[0]

# %% [markdown]
# Quality of classification (in percent)

# %%
np.mean(predicted_classes==y_test)*100
# Out:
# 94.35

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))

# %%
hist2=model.fit(X_train, Y_train,
          batch_size=512, epochs=32,
          shuffle=True,
           verbose=1,
          validation_data=(X_test, Y_test)
         )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/32
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1593 - acc: 0.9534 - val_loss: 0.1431 - val_acc: 0.9579
# Epoch 2/32
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.1116 - acc: 0.9691 - val_loss: 0.1072 - val_acc: 0.9676
# Epoch 3/32
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0864 - acc: 0.9758 - val_loss: 0.0922 - val_acc: 0.9726
# Epoch 4/32
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0692 - acc: 0.9807 - val_loss: 0.0829 - val_acc: 0.9751
# Epoch 5/32
# 60000/60000 [==============================] - 2s 36us/step - loss: 0.0558 - acc: 0.9850 - val_loss: 0.0824 - val_acc: 0.9746
# Epoch 6/32
# 60000/60000 [==============================] - 2s 37us/step - loss: 0.0475 - acc: 0.9874 - val_loss: 0.0766 - val_acc: 0.9763
# Epoch 7/32
# ...

# %%
plt.plot(hist1.history['loss']+hist2.history['loss'],label="train")
plt.plot(hist1.history['val_loss']+hist2.history['val_loss'],label="test")
plt.xlabel("# epoch")
plt.ylabel("Loss")
plt.legend()
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-1e09f680f283> in <module>
# ----> 1 plt.plot(hist1.history['loss']+hist2.history['loss'],label="train")
#       2 plt.plot(hist1.history['val_loss']+hist2.history['val_loss'],label="test")
#       3 plt.xlabel("# epoch")
#       4 plt.ylabel("Loss")
#       5 plt.legend()
#
# NameError: name 'hist2' is not defined

# %%
plt.plot(hist1.history['acc']+hist2.history['acc'],label="train")
plt.plot(hist1.history['val_acc']+hist2.history['val_acc'],label="test")
plt.xlabel("# epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.yscale('log')

# %% [markdown]
# # Convolutional neural network

# %% [markdown]
# https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/

# %%
n_images,img_rows, img_cols = X_train_orig.shape
img_rows, img_cols
# Out:
# (28, 28)

# %%
X_train_cnn = X_train_orig.reshape(X_train_orig.shape[0], img_rows, img_cols,1)
X_test_cnn = X_test_orig.reshape(X_test_orig.shape[0], img_rows, img_cols,1)

# %%
X_train_cnn = X_train_cnn.astype('float32')
X_test_cnn = X_test_cnn.astype('float32')
X_train_cnn /= 255
X_test_cnn /= 255

# %%
input_shape = (img_rows, img_cols,1)

# %%
input_shape
# Out:
# (28, 28, 1)

# %%
n_filters=10

# %%
model = Sequential()
model.add(Conv2D(n_filters, (5, 5), input_shape=input_shape, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(nb_classes, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_2 (Conv2D)            (None, 24, 24, 10)        260
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 10)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1440)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 128)               184448
# _________________________________________________________________
# dense_12 (Dense)             (None, 10)                1290
# ...
# Total params: 185,998
# Trainable params: 185,998
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist1 = model.fit(X_train_cnn[:1000], Y_train[:1000],
          batch_size=512, epochs=15,
          shuffle=True,
           verbose=1,
          validation_data=(X_test_cnn, Y_test)
         )
# Out:
# Train on 1000 samples, validate on 10000 samples
# Epoch 1/15
# 1000/1000 [==============================] - 1s 780us/step - loss: 0.0255 - acc: 1.0000 - val_loss: 0.3483 - val_acc: 0.8999
# Epoch 2/15
# 1000/1000 [==============================] - 1s 871us/step - loss: 0.0242 - acc: 1.0000 - val_loss: 0.3477 - val_acc: 0.9001
# Epoch 3/15
# 1000/1000 [==============================] - 1s 851us/step - loss: 0.0230 - acc: 1.0000 - val_loss: 0.3462 - val_acc: 0.9016
# Epoch 4/15
# 1000/1000 [==============================] - 1s 786us/step - loss: 0.0221 - acc: 1.0000 - val_loss: 0.3460 - val_acc: 0.9020
# Epoch 5/15
# 1000/1000 [==============================] - 1s 752us/step - loss: 0.0212 - acc: 1.0000 - val_loss: 0.3464 - val_acc: 0.9025
# Epoch 6/15
# 1000/1000 [==============================] - 1s 748us/step - loss: 0.0203 - acc: 1.0000 - val_loss: 0.3483 - val_acc: 0.9021
# Epoch 7/15
# ...

# %%
# The predict_classes function outputs the highest probability class
# according to the trained classifier for each input example.
predicted_classes = model.predict_classes(X_test_cnn)

# Check which items we got right / wrong
correct_indices = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test)[0]

# %% [markdown]
# Quality of classification (in percent)

# %%
np.mean(predicted_classes==y_test)*100
# Out:
# 98.13

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))

# %% [markdown]
# ## visualizing convolution layers

# %% [markdown]
# Based on "How convolutional neural networks see the world"
# https://blog.keras.io/how-convolutional-neural-networks-see-the-world.html

# %%
layer_output = model.layers[0].output

# %%
input_img = model.input

# %%
fig=plt.figure()
columns = 5
rows = 2

for filter_index in range(n_filters):

    loss = K.mean(layer_output[:, :, :, filter_index])

    # compute the gradient of the input picture wrt this loss
    grads = K.gradients(loss, input_img)[0]

    # normalization trick: we normalize the gradient
    grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

    # this function returns the loss and grads given the input picture
    iterate = K.function([input_img], [loss, grads])

    input_shape

    # we start from a gray image with some noise
    input_img_data = np.random.random(input_shape) * 20 + 128.

    step=0.5

    # run gradient ascent for 20 steps
    for i in range(100):
        loss_value, grads_value = iterate([[input_img_data]])
        input_img_data += grads_value[0] * step

    fig.add_subplot(rows, columns, filter_index+1)
    plt.imshow(input_img_data.reshape(img_rows,img_cols),cmap='gray')
    #plt.title("Filter: "+str(filter_index))    
    plt.gca().get_xaxis().set_visible(False)
    plt.gca().get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ## Deeper convolution NN

# %%
model = Sequential()
model.add(Conv2D(n_filters, (3, 3), input_shape=input_shape, activation='relu',name="conv_1"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(n_filters, (3, 3), input_shape=input_shape, activation='relu',name="conv_3"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten(name="flatten"))
model.add(Dense(128, activation='relu',name="dense_1"))
model.add(Dense(nb_classes, activation='softmax',name="dense_2"))

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv_1 (Conv2D)              (None, 26, 26, 10)        100
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 13, 13, 10)        0
# _________________________________________________________________
# conv_3 (Conv2D)              (None, 11, 11, 10)        910
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 10)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 250)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               32128
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# ...
# Total params: 34,428
# ...

# %%
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
hist1 = model.fit(X_train_cnn, Y_train,
          batch_size=512, epochs=5,
          shuffle=True,
           verbose=1,
          validation_data=(X_test_cnn, Y_test)
         )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 10s 161us/step - loss: 0.8332 - acc: 0.7715 - val_loss: 0.2668 - val_acc: 0.9225
# Epoch 2/5
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.2150 - acc: 0.9362 - val_loss: 0.1497 - val_acc: 0.9574
# Epoch 3/5
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.1391 - acc: 0.9592 - val_loss: 0.1024 - val_acc: 0.9687
# Epoch 4/5
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.1074 - acc: 0.9678 - val_loss: 0.0812 - val_acc: 0.9765
# Epoch 5/5
# 60000/60000 [==============================] - 9s 155us/step - loss: 0.0885 - acc: 0.9735 - val_loss: 0.0702 - val_acc: 0.9771

# %%
input_img=model.input

for layer in model.layers:

    if not layer.name.startswith("conv"):
        continue
        
    print(layer.name)
    layer_output = layer.output
    fig=plt.figure()
    columns = 5
    rows = 2
    for filter_index in range(layer.filters):

        loss = K.mean(layer_output[:, :, :, filter_index])

        # compute the gradient of the input picture wrt this loss
        grads = K.gradients(loss, input_img)[0]

        # normalization trick: we normalize the gradient
        grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

        # this function returns the loss and grads given the input picture
        iterate = K.function([input_img], [loss, grads])

        input_shape

        # we start from a gray image with some noise
        input_img_data = np.random.random(input_shape) * 20 + 128.

        step=0.5

        # run gradient ascent for 200 steps
        for i in range(20):
            loss_value, grads_value = iterate([[input_img_data]])
            input_img_data += grads_value[0] * step
        fig.add_subplot(rows, columns, filter_index+1)
        plt.imshow(input_img_data.reshape(img_rows,img_cols),cmap='gray')
        #fig.suptitle("Filter: "+str(filter_index))
        plt.gca().get_xaxis().set_visible(False)
        plt.gca().get_yaxis().set_visible(False)
    plt.show()
    print()
    print()
# Out:
# conv_1
# conv_3

# %% [markdown]
# # Autoencoders

# %% [markdown]
# https://blog.keras.io/building-autoencoders-in-keras.html

# %% [markdown]
# ### Plain autoencoder

# %%
# this is the size of our encoded representations
encoding_dim = 32  # 32 floats -> compression of factor 24.5, assuming the input is 784 floats

# this is our input placeholder
input_img = Input(shape=(784,))
# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation='relu')(input_img)
# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid')(encoded)

# this model maps an input to its reconstruction
autoencoder = Model(input_img, decoded)

# %%
# this model maps an input to its encoded representation
encoder = Model(input_img, encoded)

# %%
# create a placeholder for an encoded (32-dimensional) input
encoded_input = Input(shape=(encoding_dim,))
# retrieve the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-1]
# create the decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %%
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                25120
# _________________________________________________________________
# dense_6 (Dense)              (None, 784)               25872
# ...
# Total params: 50,992
# Trainable params: 50,992
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.fit(X_train, X_train,
                epochs=10,
                batch_size=256,
                shuffle=True,
                validation_data=(X_test, X_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 3s 46us/step - loss: 0.3514 - val_loss: 0.2716
# Epoch 2/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2651 - val_loss: 0.2548
# Epoch 3/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2431 - val_loss: 0.2289
# Epoch 4/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2201 - val_loss: 0.2098
# Epoch 5/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.2048 - val_loss: 0.1973
# Epoch 6/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1940 - val_loss: 0.1880
# Epoch 7/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1856 - val_loss: 0.1805
# Epoch 8/10
# 60000/60000 [==============================] - 3s 42us/step - loss: 0.1788 - val_loss: 0.1744
# Epoch 9/10
# ...

# %%
# encode and decode some digits
# note that we take them from the *test* set
encoded_imgs = encoder.predict(X_test)
decoded_imgs = decoder.predict(encoded_imgs)

# %%
n = 10  # how many digits we will display
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(X_test[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### Convolutional autoencoder

# %%
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Model
from keras import backend as K

input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (4, 4, 8) i.e. 128-dimensional

x = Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), activation='relu')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 7, 7, 8)           584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 4, 4, 8)           0
# ...

# %%
autoencoder.fit(X_train_cnn, X_train_cnn,
                epochs=10,
                batch_size=512,
                shuffle=True,
                validation_data=(X_test_cnn, X_test_cnn),
                )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 39s 648us/step - loss: 0.2939 - val_loss: 0.2150
# Epoch 2/10
# 60000/60000 [==============================] - 38s 638us/step - loss: 0.1998 - val_loss: 0.1867
# Epoch 3/10
# 60000/60000 [==============================] - 38s 639us/step - loss: 0.1814 - val_loss: 0.1730
# Epoch 4/10
# 60000/60000 [==============================] - 38s 637us/step - loss: 0.1703 - val_loss: 0.1688
# Epoch 5/10
# 60000/60000 [==============================] - 38s 637us/step - loss: 0.1617 - val_loss: 0.1545
# Epoch 6/10
# 60000/60000 [==============================] - 38s 639us/step - loss: 0.1551 - val_loss: 0.1482
# Epoch 7/10
# 60000/60000 [==============================] - 38s 638us/step - loss: 0.1497 - val_loss: 0.1444
# Epoch 8/10
# 60000/60000 [==============================] - 38s 639us/step - loss: 0.1456 - val_loss: 0.1410
# Epoch 9/10
# ...

# %%
decoded_imgs = autoencoder.predict(X_test_cnn)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(X_test_cnn[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# ### Denoising

# %%
noise_factor = 0.5
X_train_cnn_noisy = X_train_cnn + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_train_cnn.shape) 
X_test_cnn_noisy = X_test_cnn + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=X_test_cnn.shape)

# %%
X_train_cnn_noisy = np.clip(X_train_cnn_noisy, 0., 1.)
X_test_cnn_noisy = np.clip(X_test_cnn_noisy, 0., 1.)

# %%
n = 10
plt.figure(figsize=(20, 2))
for i in range(n):
    ax = plt.subplot(1, n, i+1)
    plt.imshow(X_test_cnn_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
input_img = Input(shape=(28, 28, 1))  # adapt this if using `channels_first` image data format

x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

# at this point the representation is (7, 7, 32)

x = Conv2D(32, (3, 3), activation='relu', padding='same')(encoded)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adadelta', loss='binary_crossentropy')

# %%
autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_4 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 32)        9248
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 7, 7, 32)          9248
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 14, 14, 32)        0
# ...

# %%
autoencoder.fit(X_train_cnn_noisy, X_train_cnn,
                epochs=10,
                batch_size=128,
                shuffle=True,
                validation_data=(X_test_cnn_noisy, X_test_cnn),
                )
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 84s 1ms/step - loss: 0.1782 - val_loss: 0.1259
# Epoch 2/10
# 60000/60000 [==============================] - 84s 1ms/step - loss: 0.1198 - val_loss: 0.1177
# Epoch 3/10
# 60000/60000 [==============================] - 84s 1ms/step - loss: 0.1126 - val_loss: 0.1105
# Epoch 4/10
# 60000/60000 [==============================] - 84s 1ms/step - loss: 0.1091 - val_loss: 0.1070
# Epoch 5/10
# 60000/60000 [==============================] - 84s 1ms/step - loss: 0.1068 - val_loss: 0.1032
# Epoch 6/10
# 50944/60000 [========================>.....] - ETA: 12s - loss: 0.1056
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-0a258d57a04f> in <module>()
#       3                 batch_size=128,
#       4                 shuffle=True,
# ...

# %% [markdown]
# denoising the noisy images

# %%
decoded_imgs = autoencoder.predict(X_test_cnn_noisy)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(X_test_cnn_noisy[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %% [markdown]
# denoising the normal images

# %%
decoded_imgs = autoencoder.predict(X_test_cnn)

n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # display original
    ax = plt.subplot(2, n, i+1)
    plt.imshow(X_test_cnn[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    ax = plt.subplot(2, n, i + n+1)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
